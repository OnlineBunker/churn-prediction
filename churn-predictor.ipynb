# %% [markdown]
# <a href="https://colab.research.google.com/github/OnlineBunker/churn-prediction/blob/main/churn-predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
